# %%
# In[ ]:
# ---- Query set (domain questions) ----
Q = [
    "What are the knobs that can change the uniformity in radical si-etching process?",
    "How to increase the selectivity ratio of Si to oxide in ICP etching?",
    "How to reduce the particle in the dechuck step of etching?",
    "How to improve the cleaning or etching ability of Al particles?",
    (
        "Two-stage etching on poly-silicon:\n"
        "Stage-1: HAR etch, 30 nm width, 100 nm depth.\n"
        "Stage-2: selectivity 22:1 (poly-silicon:SiO2), extra 45 nm depth, base STI OX."
    ),
    "How to achieve ~70° taper using Cl2/HBr/O2 on silicon?",
    "On a trench 15 nm (W) × 75 nm (D), how to etch SiGe bottom 10 nm and SiP 5 nm?",
    "How to increase oxidizing power of O2/H2 radical on W sidewall in HAR (15×75 nm)?",
    "How to reduce SiN etching at the bottom of a 15×70 nm trench without bowing?",
    "How to reduce iso-dense CD loading on silicon etching?",
]

# %%
import os
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from peft import PeftModel

os.environ["HF_HUB_OFFLINE"] = "1"

BASE_MODEL_DIR = "/home/mkychsu/pool/llm/Llama-3.1-8B-Instruct"
ADAPTER_DIR = "/home/mkychsu/pool/path/to/orpg_graph_model/checkpoint-487"   # <-- real full path

device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.bfloat16 if device == "cuda" else torch.float32

assert os.path.isdir(BASE_MODEL_DIR), BASE_MODEL_DIR
assert os.path.isdir(ADAPTER_DIR), ADAPTER_DIR

print("BASE files:", os.listdir(BASE_MODEL_DIR))
print("ADAPTER files:", os.listdir(ADAPTER_DIR))

# tokenizer: load from adapter dir only if tokenizer files were saved there
tokenizer_dir = ADAPTER_DIR if os.path.exists(os.path.join(ADAPTER_DIR, "tokenizer_config.json")) else BASE_MODEL_DIR

tokenizer = AutoTokenizer.from_pretrained(
    tokenizer_dir,
    local_files_only=True,
    use_fast=False,
)

if tokenizer.pad_token_id is None:
    tokenizer.pad_token = tokenizer.eos_token

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL_DIR,
    local_files_only=True,
    trust_remote_code=True,
    torch_dtype=dtype,
    device_map="auto" if device == "cuda" else None,
)

base_model.resize_token_embeddings(len(tokenizer))

model = PeftModel.from_pretrained(
    base_model,
    ADAPTER_DIR,
    local_files_only=True,
)

model.eval()
# Out:
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/transformers/utils/hub.py:479, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     477 if len(full_filenames) == 1:
#     478     # This is slightly better for only 1 file
# --> 479     hf_hub_download(
#     480         path_or_repo_id,
#     481         filenames[0],
#     482         subfolder=None if len(subfolder) == 0 else subfolder,
#     483         repo_type=repo_type,
#     484         revision=revision,
#     485         cache_dir=cache_dir,
#     486         user_agent=user_agent,
#     487         force_download=force_download,
#     488         proxies=proxies,
#     489         resume_download=resume_download,
#     490         token=token,
#     491         local_files_only=local_files_only,
#     492     )
#     493 else:
#
# File ~/.local/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     105 if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106     validate_repo_id(arg_value)
#     108 elif arg_name == "token" and arg_value is not None:
#
# File ~/.local/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '../orpg_graph_model/checkpoint-487'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# Cell In[9], line 14
#      11 dtype = torch.bfloat16 if device == "cuda" else torch.float32
#      13 # 1) tokenizer must come from checkpoint
# ---> 14 tokenizer = AutoTokenizer.from_pretrained(
#      15     CKPT_DIR,
#      16     local_files_only=True,
#      17     use_fast=False,
#      18 )
#      20 if tokenizer.pad_token_id is None:
#      21     tokenizer.pad_token = tokenizer.eos_token
#
# File ~/.local/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:1089, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#    1086     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
#    1088 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
# -> 1089 tokenizer_config = get_tokenizer_config(pretrained_model_name_or_path, **kwargs)
#    1090 if "_commit_hash" in tokenizer_config:
#    1091     kwargs["_commit_hash"] = tokenizer_config["_commit_hash"]
#
# File ~/.local/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:921, in get_tokenizer_config(pretrained_model_name_or_path, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, **kwargs)
#     918     token = use_auth_token
#     920 commit_hash = kwargs.get("_commit_hash")
# --> 921 resolved_config_file = cached_file(
#     922     pretrained_model_name_or_path,
#     923     TOKENIZER_CONFIG_FILE,
#     924     cache_dir=cache_dir,
#     925     force_download=force_download,
#     926     resume_download=resume_download,
#     927     proxies=proxies,
#     928     token=token,
#     929     revision=revision,
#     930     local_files_only=local_files_only,
#     931     subfolder=subfolder,
#     932     _raise_exceptions_for_gated_repo=False,
#     933     _raise_exceptions_for_missing_entries=False,
#     934     _raise_exceptions_for_connection_errors=False,
#     935     _commit_hash=commit_hash,
#     936 )
#     937 if resolved_config_file is None:
#     938     logger.info("Could not locate the tokenizer configuration file, will try to use the model config instead.")
#
# File ~/.local/lib/python3.11/site-packages/transformers/utils/hub.py:322, in cached_file(path_or_repo_id, filename, **kwargs)
#     264 def cached_file(
#     265     path_or_repo_id: Union[str, os.PathLike],
#     266     filename: str,
#     267     **kwargs,
#     268 ) -> Optional[str]:
#     269     """
#     270     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     271
#    (...)
#     320     ```
#     321     """
# --> 322     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     323     file = file[0] if file is not None else file
#     324     return file
#
# File ~/.local/lib/python3.11/site-packages/transformers/utils/hub.py:531, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     524     raise OSError(
#     525         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     526         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     527         "2) a previous download was canceled and the lock file needs manual removal."
#     528     ) from e
#     530 # Now we try to recover if we can find all files correctly in the cache
# --> 531 resolved_files = [
#     532     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     533     for filename in full_filenames
#     534 ]
#     535 if all(file is not None for file in resolved_files):
#     536     return resolved_files
#
# File ~/.local/lib/python3.11/site-packages/transformers/utils/hub.py:532, in <listcomp>(.0)
#     524     raise OSError(
#     525         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     526         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     527         "2) a previous download was canceled and the lock file needs manual removal."
#     528     ) from e
#     530 # Now we try to recover if we can find all files correctly in the cache
#     531 resolved_files = [
# --> 532     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     533     for filename in full_filenames
#     534 ]
#     535 if all(file is not None for file in resolved_files):
#     536     return resolved_files
#
# File ~/.local/lib/python3.11/site-packages/transformers/utils/hub.py:143, in _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision, repo_type)
#     135 def _get_cache_file_to_return(
#     136     path_or_repo_id: str,
#     137     full_filename: str,
#    (...)
#     141 ):
#     142     # We try to see if we have a cached version (not up to date):
# --> 143     resolved_file = try_to_load_from_cache(
#     144         path_or_repo_id, full_filename, cache_dir=cache_dir, revision=revision, repo_type=repo_type
#     145     )
#     146     if resolved_file is not None and resolved_file != _CACHED_NO_EXIST:
#     147         return resolved_file
#
# File ~/.local/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:106, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     101 for arg_name, arg_value in chain(
#     102     zip(signature.parameters, args),  # Args values
#     103     kwargs.items(),  # Kwargs values
#     104 ):
#     105     if arg_name in ["repo_id", "from_id", "to_id"]:
# --> 106         validate_repo_id(arg_value)
#     108     elif arg_name == "token" and arg_value is not None:
#     109         has_token = True
#
# File ~/.local/lib/python3.11/site-packages/huggingface_hub/utils/_validators.py:154, in validate_repo_id(repo_id)
#     151     raise HFValidationError(f"Repo id must be a string, not {type(repo_id)}: '{repo_id}'.")
#     153 if repo_id.count("/") > 1:
# --> 154     raise HFValidationError(
#     155         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     156         f" '{repo_id}'. Use `repo_type` argument if needed."
#     157     )
#     159 if not REPO_ID_REGEX.match(repo_id):
#     160     raise HFValidationError(
#     161         "Repo id must use alphanumeric chars, '-', '_' or '.'."
#     162         " The name cannot start or end with '-' or '.' and the maximum length is 96:"
#     163         f" '{repo_id}'."
#     164     )
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': '../orpg_graph_model/checkpoint-487'. Use `repo_type` argument if needed.
